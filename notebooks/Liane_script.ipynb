# %%
import pandas as pd

# %% [markdown]
# ## creating a dataframe like what i have in sql

# %%
authors_data = {
    "author_id": [],
    "first_name": [],
    "last_name": [],
    "email":[],
    "nationality": [],
    
}

authors= pd.DataFrame(authors_data)
authors
# Out:
# Empty DataFrame
# Columns: [author_id, first_name, last_name, email, nationality]
# Index: []

# %%
book_copies_data = {
    "copy_id": [],
    "isbn": [],
    "status": [],
    
}

book_copies= pd.DataFrame(book_copies_data)
book_copies
# Out:
# Empty DataFrame
# Columns: [copy_id, isbn, status]
# Index: []

# %%
book_loans_data = {
    "loan_id": [],
    "isbn": [],
    "member_id": [],
    "borrowed_date":[],
    "due_date": [],
    "returned_date": []
    
}

book_loans= pd.DataFrame(book_loans_data)
book_loans
# Out:
# Empty DataFrame
# Columns: [loan_id, isbn, member_id, borrowed_date, due_date, returned_date]
# Index: []

# %%
books_data = {
    "isbn": [],
    "title": [],
    "publication_year": [],
    "language":[],
    "publisher_id": [],
    "author_id": []
    
}

books= pd.DataFrame(books_data)
books
# Out:
# Empty DataFrame
# Columns: [isbn, title, publication_year, language, publisher_id, author_id]
# Index: []

# %%
members_data = {
    "member_id": [],
    "first_name": [],
    "last_name": [],
    "email":[],
    "phone": [],
    "address": [],
    "join_date": []
    
}

members= pd.DataFrame(members_data)
members
# Out:
# Empty DataFrame
# Columns: [member_id, first_name, last_name, email, phone, address, join_date]
# Index: []

# %%
publishers_data = {
    "publisher_id": [],
    "publisher_name": [],
    "country": [],
}

publishers= pd.DataFrame(publishers_data)
publishers
# Out:
# Empty DataFrame
# Columns: [publisher_id, publisher_name, country]
# Index: []

# %%
schema = "liane_library"
host = "127.0.0.1"
user = "root"
password = "Ayodeji007!"
port = 3306

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %%
authors
# Out:
# Empty DataFrame
# Columns: [author_id, first_name, last_name, email, nationality]
# Index: []

# %%
authors['first_name'] = ["Ayodeji", "Blessy", "Andreas", "Anna", "Kelvin"]

# %%
authors
# Out:
#    author_id first_name  last_name  email  nationality
# 0        NaN    Ayodeji        NaN    NaN          NaN
# 1        NaN     Blessy        NaN    NaN          NaN
# 2        NaN    Andreas        NaN    NaN          NaN
# 3        NaN       Anna        NaN    NaN          NaN
# 4        NaN     Kelvin        NaN    NaN          NaN

# %%
authors['last_name'] = ["Abajingin", "Asir", "Politzer", "Kuksa", "Purdom"]
authors['email'] = ["abajinginayodeji@gmail.com", "blessyasir@gmail.com", "andreaspolitzer@gmail.com", "annakuksa@gmail.com", "kelvinpurdom@gmail.com"]
authors['nationality'] = ["Nigerian", "Indian", "German", "Ukranian", "Scotish"]

# %%
authors
# Out:
#    author_id first_name  last_name                       email nationality
# 0        NaN    Ayodeji  Abajingin  abajinginayodeji@gmail.com    Nigerian
# 1        NaN     Blessy       Asir        blessyasir@gmail.com      Indian
# 2        NaN    Andreas   Politzer   andreaspolitzer@gmail.com      German
# 3        NaN       Anna      Kuksa         annakuksa@gmail.com    Ukranian
# 4        NaN     Kelvin     Purdom      kelvinpurdom@gmail.com     Scotish

# %%
# !pip install sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 653.6 kB/s eta 0:00:04
#     --------------------------------------- 0.0/2.1 MB 653.6 kB/s eta 0:00:04
#     --------------------------------------- 0.0/2.1 MB 653.6 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/2.1 MB 595.3 kB/s eta 0:00:04
#    --- ------------------------------------ 0.2/2.1 MB 737.3 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.3/2.1 MB 1.1 MB/s eta 0:00:02
#    ------- -------------------------------- 0.4/2.1 MB 1.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.6/2.1 MB 1.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.6/2.1 MB 1.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.6/2.1 MB 1.5 MB/s eta 0:00:02
# ...

# %%
import sqlalchemy

print(sqlalchemy.__version__)
# Out:
# 2.0.51

# %%
# !pip install pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/45.7 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/45.7 kB ? eta -:--:--
#    ----------------------------------- ---- 41.0/45.7 kB 487.6 kB/s eta 0:00:01
#    ---------------------------------------- 45.7/45.7 kB 377.4 kB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.3.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pymysql

print("PyMySQL installed successfully")
# Out:
# PyMySQL installed successfully

# %%
from sqlalchemy import create_engine
import pymysql

# %%
engine = create_engine(
    "mysql+pymysql://root:Ayodeji007!@localhost/liane_library"
)

connection = engine.connect()
print("Connected!")
# Out:
# Connected!

# %%
authors.to_sql('authors',
                    if_exists = 'append',
                    con = connection_string,
                    index = False)
# Out:
# 5

# %%
books
# Out:
# Empty DataFrame
# Columns: [isbn, title, publication_year, language, publisher_id, author_id]
# Index: []

# %%
books["isbn"] = ["0000000000001", "0000000000002", "0000000000003", "0000000000004", "0000000000005"]
books["title"] = ["The Silent Map of Forgotten Roads", "When the Ocean Remembers", "The Clockmaker’s Last Secret", "Beyond the Glass Horizon", "The Garden Where Shadows Bloom"]
books["publication_year"] = [1989, 2000, 2003, 1965, 1996]
books["language"] = ["English", "English", "English", "English", "English"]
books["publisher_id"] = [1, 2, 3,4, 5 ]
books["author_id"] = [1,2,3,4,5]

books.to_sql('books',
                    if_exists = 'append',
                    con = connection_string,
                    index = False)
# Out:
# 5

# %%
members
# Out:
# Empty DataFrame
# Columns: [member_id, first_name, last_name, email, phone, address, join_date]
# Index: []

# %%
members["first_name"] = ["Paul", "Heinrich", "Cynthia", "Jasmine", "Steven"]
members["last_name"] = ["Brenard", "Ludwig", "Ciara", "Koch", "Burner"]
members["email"] = ["Paulbrenard@gmail.com", "Heinrichludwig@gmail.com", "Cynthiaciara@gmail.com", "Jasminekoch@gmail.com", "Stevenburner@gmail.com"]
members["phone"] = ["013467373885", "015976542434", "015765435786", "015634679853", "017624005539"]
members["address"] = ["orionweg 5", "Auf dem Knüll 77", "Bielefelderstrasse 45", "Gütersloherstrasse 67", "Montcenis strasse 32" ]
members["join_date"] = pd.to_datetime([
    "23-05-2003",
    "12-04-2020",
    "13-05-2007",
    "27-06-2002",
    "25-08-2002"
], dayfirst=True)



members.to_sql('members',
                    if_exists = 'append',
                    con = connection_string,
                    index = False)
# Out:
# 5

# %%
publishers
# Out:
# Empty DataFrame
# Columns: [publisher_id, publisher_name, country]
# Index: []

# %%
publishers["publisher_name"] = ["Horizon Press", "Blue Oak Publishing", "Emerald Leaf Books", "Alpen Verlag", "Sakura House Publishing"]
publishers["country"] = ["Unitee States", "Canada", "United Kingdom", "Germany", "Japan"]

publishers.to_sql('publishers',
                    if_exists = 'append',
                    con = connection_string,
                    index = False)
# Out:
# 5

# %%
book_loans
# Out:
# Empty DataFrame
# Columns: [loan_id, isbn, member_id, borrowed_date, due_date, returned_date]
# Index: []

# %%
book_loans["isbn"] = ["0000000000001", "0000000000002", "0000000000003", "0000000000004", "0000000000005"]
book_loans["member_id"] = [1, 2, 3, 4, 5]
book_loans["borrowed_date"] = pd.to_datetime([
    "23-01-2026",
    "13-02-2026",
    "10-10-2025",
    "15-11-2025",
    "13-12-2025"
], dayfirst=True)

book_loans["due_date"] = pd.to_datetime([
    "23-02-2026",
    "13-03-2026",
    "10-11-2026",
    "15-12-2025",
    "13-01-2026"
], dayfirst=True)

book_loans["returned_date"] = pd.to_datetime([
    "15-03-2026",
    "12-03-2026",
    "08-11-2026",
    "16-12-2025",
    "17-01-2026"
], dayfirst=True)


book_loans.to_sql('book_loans',
                    if_exists = 'append',
                    con = connection_string,
                    index = False)
# Out:
# 5

# %%
book_copies
# Out:
# Empty DataFrame
# Columns: [copy_id, isbn, status]
# Index: []

# %%
book_copies["isbn"] = ["0000000000001", "0000000000002", "0000000000003", "0000000000004", "0000000000005"]
book_copies["status"] = ["Available", "Available", "Available", "Available", "Available"]

book_copies.to_sql('book_copies',
                    if_exists = 'append',
                    con = connection_string,
                    index = False)
# Out:
# 5

# %%
# Define the update query
update_query = """
    UPDATE Movies
    SET MovieTitle = "Thelma & Louise"
    WHERE MovieId = 3;
"""

# Execute the update query with an explicit commit
with engine.connect() as connection:
    transaction = connection.begin()
    try:
        connection.execute(text(update_query))
        transaction.commit()
    except:
        transaction.rollback()
        raise
